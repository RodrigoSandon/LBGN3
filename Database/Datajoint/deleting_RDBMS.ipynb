# %%
import datajoint as dj
import datetime
import os, glob
import re
import pandas as pd
import numpy as np


dj.config['database.host'] = 'localhost'
dj.config['database.user'] = 'root'
dj.config['database.password'] = 'twiceblackpink9.'

schema = dj.schema('RDBMS', locals())
schema.drop()  # comment out to keep the schema
# Out:
# Connecting root@localhost:3306
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-83f2fcdbaa1c> in <module>
#       5 import pandas as pd
#       6 import numpy as np
# ----> 7 from RDBMS_tables import *
#       8
#       9
#
# /media/rory/Padlock_DT/Rodrigo/Database/Datajoint/RDBMS_tables.py in <module>
#      11
#      12 @schema
# ---> 13 class Mouse(dj.Manual):
#      14     definition = """
#      15         # mouse
#
# ~/anaconda3/envs/bla_alignment/lib/python3.6/site-packages/datajoint/schemas.py in __call__(self, cls, context)
#     145             raise DataJointError('The schema decorator should not be applied to Part relations')
#     146         if self.is_activated():
# --> 147             self._decorate_master(cls, context)
#     148         else:
#     149             self.declare_list.append((cls, context))
#
# ...
